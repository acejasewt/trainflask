# %%
from flask import Flask, redirect, url_for, render_template, request, session, jsonify,flash
from flask_mysqldb import MySQL
import random, cv2

# %%
#人臉辨識
def facedetect():
    face_cascade =  cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
    cap = cv2.VideoCapture(0)
    while 1:
        ret,frame = cap.read()
        cv2.imshow('frame',frame)

        gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

        faces = face_cascade.detectMultiScale(gray, scaleFactor = 1.08, minNeighbors = 10, minSize = (32, 32))
        if len(faces) != 0: 
            if cv2.waitKey(0):
                break

    cap.release()
    cv2.destroyAllWindows()
    return 1

# %%
app = Flask(__name__)

app.config["MYSQL_HOST"] = "localhost"
app.config["MYSQL_USER"] = "root"
app.config["MYSQL_PASSWORD"] = ""
app.config["MYSQL_DB"] = "railway"
app.config['JSON_AS_ASCII'] = False
app.secret_key = "jijijijpjpjpjpjpjpjpjp"

mysql = MySQL(app)

# %%
#首頁
@app.route("/")
@app.route("/index",methods=["POST","GET"])
def home():
    if request.method == "GET":
        return render_template("index.html")
    
#車站景點
@app.route("/intro",methods=["POST","GET"])
def intro():
    if request.method == "GET":
        return render_template("intro.html")

#查詢時刻表
@app.route("/booking",methods=["POST","GET"])
def booking():
    if request.method == "GET":
        return render_template("booking.html")
    else:
        dep = request.form["departure"]
        des = request.form["destination"]
        cur = mysql.connection.cursor()
        cur.execute("SELECT * FROM `schedule` WHERE destination = %s AND departure = %s",(des,dep))
        fetchdata = cur.fetchall()
        cur.close()
        srhdata = []
        content = {}

        for i in fetchdata:
            randfull = random.randint(20,150)
            tmpdep = i[9] if len(i[9])==5 else "0"+i[9]
            tmpdes = i[10] if len(i[10])==5 else "0"+i[10]
            content = {"train_type":i[4],"train_num":i[6],"dep_time":tmpdep,"des_time":tmpdes,"full":randfull,"child":randfull//2,"eld":randfull//2,"remain":random.randint(0,12),"train_id":i[5]}
            srhdata.append(content)
            content = {}
        session["srhres"] = srhdata
        return redirect(url_for("bookingres"))
    
#訂票
@app.route("/book",methods=["POST","GET"])
def rlbook():
    if request.method == "GET":
        cur = mysql.connection.cursor()
        cur.execute("SELECT * FROM `schedule` WHERE id = %s",(session["trainid"],))
        booktrain = cur.fetchone()
        cur.close()
        tmpdep = booktrain[9] if len(booktrain[9])==5 else "0"+booktrain[9]
        tmpdes = booktrain[10] if len(booktrain[10])==5 else "0"+booktrain[10]
        getbook = {"rlnm":session['realnm'],"date":"2021/06/13","bgtime":tmpdep,"edtime":tmpdes,"train_type":booktrain[4],"train_num":booktrain[6],"dep":booktrain[7],"des":booktrain[8]}
            
        session["getbook"] = getbook
        return render_template("realbooking.html")
    else:
        adult = request.form["adult"]
        eld = request.form["eld"]
        child = request.form["child"]
            
        cur = mysql.connection.cursor()
        cur.execute("INSERT INTO journey (id,username,child,adult,elder) VALUES (%s, %s, %s, %s, %s)",(session["trainid"],session["user"],child,adult,eld,))
        mysql.connection.commit()
        return redirect(url_for("bookinghis"))

#查詢結果
@app.route("/bookingres",methods=["POST","GET"])
def bookingres():
    if request.method == "GET":
        return render_template("bookingres.html")
    else:
        if "user" in session:
            idval = request.form["trainid"]
            session["trainid"] = idval
            return redirect(url_for("rlbook"))
        else:
            flash("欲訂票請先登入!")
            return redirect(url_for("login"))
    
#知識王
@app.route("/knowledge",methods=["POST","GET"])
def knowledge():
    if request.method == "GET":
        return render_template("knowledge.html")

#初階測驗
@app.route("/test1",methods=["POST","GET"])
def test1():
    if request.method == "GET":
        return render_template("test1.html")
    
#初階測驗
@app.route("/test2",methods=["POST","GET"])
def test2():
    if request.method == "GET":
        return render_template("test2.html")

#登入
@app.route("/login",methods=["POST","GET"])
def login():
    global fetchdata_user
    
    if "user" not in session:
        if request.method == "GET":
            return render_template("login.html")
        else:
            if "facedetect" in session:
                if session["facedetect"]:
                    user = request.form["usrname"]
                    password = request.form["usrpw"]

                    cur = mysql.connection.cursor()
                    cur.execute("SELECT * FROM `userinfo` WHERE username = %s",(user,))
                    fetchdata_user = cur.fetchone()
                    cur.close()

                    if fetchdata_user :
                        if password == fetchdata_user[1]:
                            session['user'] = user
                            session['pass'] = fetchdata_user[1]
                            session['realnm'] = fetchdata_user[2]
                            session['mail'] = fetchdata_user[3]
                            session['phone'] = fetchdata_user[4]

                            return redirect(url_for("home"))
                        else:
                            flash("密碼輸入錯誤")
                    else:
                        flash("使用者名稱錯誤!")
            else:
                flash("尚未逕行人臉辨識或辨識失敗")
            return redirect(url_for("login"))
    else:
        return redirect(url_for("home"))
    
#人臉辨識
@app.route("/facedetect")
def face():
    if facedetect():
        flash("人臉辨識成功")
        session["facedetect"] = 1
    else:
        flash("人臉辨識失敗")
        session["facedetect"] = 0
    return redirect(url_for("login"))

#註冊
@app.route("/register",methods=["POST","GET"])
def register():
    if "user" not in session:
        if request.method == "GET":
            return render_template("register.html")
        else:
            mail = request.form["mail"]

            cur = mysql.connection.cursor()
            cur.execute("SELECT * FROM `userinfo` WHERE mail = %s",(mail,))
            check_mail = cur.fetchone()
            cur.close()
            if check_mail:
                flash("信箱已被使用!")
                return redirect(url_for("register"))
            else:
                usr = request.form['usrname']
                cur = mysql.connection.cursor()
                cur.execute("SELECT * FROM `userinfo` WHERE username = %s",(usr,))
                check_usr = cur.fetchone()
                cur.close()
                if check_usr:
                    flash("名稱已被使用!")
                    return redirect(url_for("register"))
                else:
                    pw = request.form["usrpw"]
                    checkpw = request.form["checkpw"]
                    if pw == checkpw:
                        usrnm = request.form["realname"]
                        phone = request.form["phone"]
                        cur = mysql.connection.cursor()
                        cur.execute("INSERT INTO userinfo (username,password,real_name,mail,phone) VALUES (%s, %s, %s, %s, %s)",(usr,pw,usrnm,mail,phone,))
                        mysql.connection.commit()

                        return render_template("login.html")
                    else:
                        flash("密碼驗證不正確!")
                        return redirect(url_for("register"))
    else:
        return redirect(url_for("home"))

#帳戶總覽
@app.route("/overview")
def oveview():
    if "user" in session:
        if "bookhis" not in session:
            cur = mysql.connection.cursor()
            cur.execute("SELECT * FROM `journey` WHERE username = %s",(session["user"],))
            booking_data = cur.fetchall()
            bookinfo = []
            tmpdata = {}
            for i in booking_data:
                cur.execute("SELECT * FROM `schedule` WHERE id = %s",(i[0],))
                train_info = cur.fetchone()
                tmpdep = train_info[9] if len(train_info[9])==5 else "0"+train_info[9]
                tmpdes = train_info[10] if len(train_info[10])==5 else "0"+train_info[10]
                tmpdata = {"dep":train_info[7],"des":train_info[8],"dep_time":tmpdep,"dep_time":tmpdep,"des_time":tmpdes,"train_type":train_info[4],"full":i[3],"child":i[2],"eld":i[4]}
                bookinfo.append(tmpdata)
            cur.close()
            session["bookhis"] = bookinfo
        return render_template("account_overview.html")
    else:
        return redirect(url_for("home"))

#訂票紀錄
@app.route("/bookinghis",methods=["POST","GET"])
def bookinghis():
    if "user" in session:
        if request.method == "GET":
            if "bookhis" not in session:
                cur = mysql.connection.cursor()
                cur.execute("SELECT * FROM `journey` WHERE username = %s",(session["user"],))
                booking_data = cur.fetchall()
                bookinfo = []
                tmpdata = {}
                for i in booking_data:
                    cur.execute("SELECT * FROM `schedule` WHERE id = %s",(i[0],))
                    train_info = cur.fetchone()
                    tmpdep = train_info[9] if len(train_info[9])==5 else "0"+train_info[9]
                    tmpdes = train_info[10] if len(train_info[10])==5 else "0"+train_info[10]
                    tmpdata = {"dep":train_info[7],"des":train_info[8],"dep_time":tmpdep,"dep_time":tmpdep,"des_time":tmpdes,"train_type":train_info[4],"full":i[3],"child":i[2],"eld":i[4]}
                    bookinfo.append(tmpdata)
                cur.close()
                session["bookhis"] = bookinfo
            return render_template("bookinghis.html")
    else:
        return redirect(url_for("home"))

#修改個資
@app.route("/change",methods=["POST","GET"])
def change():
    if "user" in session:
        if request.method == "GET":
            return render_template("change.html")
        else:
            tmppw = request.form["pw"] if request.form["pw"] != "" else fetchdata_user[1]
            tmpcheckpw = request.form["repw"] if request.form["repw"] != "" else fetchdata_user[1]
            tmprlnm = request.form["rlnm"] if request.form["rlnm"] != "" else fetchdata_user[2]
            tmpmail = request.form["mail"] if request.form["mail"] != "" else fetchdata_user[3]
            tmpphone = request.form["phone"] if request.form["phone"] != "" else fetchdata_user[4]
            
            if tmppw == tmpcheckpw:
                cur = mysql.connection.cursor()
                cur.execute("UPDATE `userinfo` SET password = %s, real_name = %s, mail = %s, phone = %s WHERE username = %s",(tmppw,tmprlnm,tmpmail,tmpphone,fetchdata_user[0],))
                mysql.connection.commit()
                tmpusr = request.form["usrname"] if request.form["usrname"] != "" else fetchdata_user[0]
                cur = mysql.connection.cursor()
                cur.execute("UPDATE `userinfo` SET username = %s WHERE mail = %s",(tmpusr,tmpmail,))
                mysql.connection.commit()
                session['user'] = tmpusr
                session['pass'] = tmppw
                session['realnm'] = tmprlnm
                session['mail'] = tmpmail
                session['phone'] = tmpphone
                flash("修改完成")
            else:
                flash("密碼驗證不正確!")
            return redirect(url_for("change"))
    else:
        return redirect(url_for("home"))

#登出
@app.route("/logout")
def logout():
    if "user" in session:
        session.pop("user",None)
        session.pop("msg",None)
        session.pop("realnm",None)
        session.pop("mail",None)
        session.pop("phone",None)
        session.pop("srhres",None)
        session.pop("bookhis",None)
        session.pop("facedetect",None)
        session.pop("getbook",None)
        session.pop("trainid",None)
    return redirect(url_for("home"))

# %%
if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on http://127.0.0.1:5000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [13/Jun/2021 17:44:14] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:44:14] "GET /static/css/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:44:14] "GET /static/img/main_bg1.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:44:14] "GET /static/img/ad.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:44:14] "GET /static/img/Group%201.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:44:14] "GET /favicon.ico HTTP/1.1" 404 -
# 127.0.0.1 - - [13/Jun/2021 17:45:18] "GET /booking HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:45:18] "GET /static/css/style_booking.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:45:18] "GET /static/img/ad2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:45:35] "POST /booking HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Jun/2021 17:45:35] "GET /bookingres HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:45:41] "POST /bookingres HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Jun/2021 17:45:41] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:45:41] "GET /static/css/flash_msg.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:45:41] "GET /static/css/style_login.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:45:41] "GET /static/js/script_login.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:45:41] "GET /static/img/login.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:32] "GET /facedetect HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Jun/2021 17:46:32] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:43] "POST /login HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Jun/2021 17:46:43] "GET /index HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:43] "GET /static/img/usrimg.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /intro HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/css/style_intro.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/css/style_intro_intro.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/css/style_intro_introbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/css/style_intro_carousel2.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/js/script_intro_introin.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/css/style_intro_carousel3.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/js/script_intro.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/js/script_intro_intro.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/js/script_intro_intro2.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/js/script_intro_intro3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/js/script_introin2.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/js/script_introin3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/js/script_backtointro.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:46] "GET /static/img/lsc1.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc3.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/white.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/侯硐貓村.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/內灣老街.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/十分瀑布.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/十分老街.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/台東鐵道藝術村.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/台泥DAKA園區.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/國立科學工藝博物館.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/大甲鎮瀾宮.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/train/DR2800型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/bg2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/secret/富岡車輛基地.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/內獅車站.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/三貂嶺車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/secret/臺東舊站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/八斗子車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/奇美博物館.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/客家圓樓.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/崎頂子母隧道.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/扇形車庫.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/星巴克新豐門市.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/林先生廟.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/橋頭糖廠.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/櫻木平交道.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/水里蛇窯.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/池上飯包文化故事館.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/海洋科技博物館.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/深澳鐵道自行車.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/湯圍溝溫泉公園.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/玉里舊鐵橋.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/福井食堂.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/福隆海水浴場.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/羅東林業文化園區.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/臺中舊火車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/菁桐老街.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/蓮池潭.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/赤崁樓.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/鐵道部園區.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/lsc/阿里山森林鐵路車庫園區.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/勝興車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/合興車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/和仁車站.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/多良車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/大華車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/太麻里車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/山里車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/崎頂車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/成功車站.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/望古車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/枋山車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/牡丹車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/石城車站.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/石榴車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/石龜車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/追分車站.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/station/集集車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/secret/桃林鐵馬道.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:47] "GET /static/img/secret/魚藤坪斷橋.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /knowledge HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/css/style_know.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/css/style_know_test.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/css/style_know_intro.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/css/style_know_introbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/css/style_know_his.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/js/script_know.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/js/script_introin.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/js/script_know_intro.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/js/script_hisbox.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/know1.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/know2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/know3.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/E1000型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/DR3100型.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/E200型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/E400型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/EMU1200型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/EMU300型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/test2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/hiscard2.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/hiscard1.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/main_bg2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/test1.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/EMU500型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/EMU800型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/EMU700型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/EMU600型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/R100型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/R150型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/R20型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/TEMU1000型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/train/TEMU2000型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:50] "GET /static/img/hiscard3.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:54] "GET /overview HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:46:54] "GET /static/css/style_overview.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:01] "GET /bookinghis HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:03] "GET /change HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:03] "GET /static/css/flash_msg.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:03] "GET /static/js/script_change.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /intro HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/css/style_intro_intro.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/css/style_intro.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/css/style_intro_introbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/css/style_intro_carousel2.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/css/style_intro_carousel3.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/js/script_intro_introin.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/js/script_intro.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/js/script_intro_intro.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/js/script_intro_intro2.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/js/script_intro_intro3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/js/script_introin2.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/js/script_introin3.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/img/bg2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/img/station/八斗子車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:05] "GET /static/img/station/三貂嶺車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc3.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/train/DR2800型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/內獅車站.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/secret/臺東舊站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/內灣老街.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc1.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/侯硐貓村.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/secret/富岡車輛基地.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/white.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/js/script_backtointro.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/十分瀑布.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/台泥DAKA園區.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/台東鐵道藝術村.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/十分老街.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/國立科學工藝博物館.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/奇美博物館.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/大甲鎮瀾宮.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/客家圓樓.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/崎頂子母隧道.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/扇形車庫.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/星巴克新豐門市.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/林先生廟.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/橋頭糖廠.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/櫻木平交道.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/水里蛇窯.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/池上飯包文化故事館.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/海洋科技博物館.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/深澳鐵道自行車.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/湯圍溝溫泉公園.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/玉里舊鐵橋.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/福井食堂.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/福隆海水浴場.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/羅東林業文化園區.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/臺中舊火車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/菁桐老街.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/蓮池潭.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/赤崁樓.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/鐵道部園區.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/lsc/阿里山森林鐵路車庫園區.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/勝興車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/合興車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/和仁車站.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/多良車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/大華車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/太麻里車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/山里車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/崎頂車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/成功車站.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/望古車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/枋山車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/牡丹車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/石城車站.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/石榴車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/石龜車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/追分車站.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/station/集集車站.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/secret/桃林鐵馬道.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:06] "GET /static/img/secret/魚藤坪斷橋.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:07] "GET /index HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:08] "GET /static/css/style.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:08] "GET /static/img/main_bg1.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:08] "GET /static/img/ad.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /knowledge HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/css/style_know.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/css/style_know_introbox.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/css/style_know_test.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/css/style_know_intro.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/js/script_introin.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/css/style_know_his.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/js/script_know.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/js/script_know_intro.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/js/script_hisbox.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/know1.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/know2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/know3.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/train/DR2800型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/test1.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/main_bg2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/hiscard1.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/hiscard2.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/train/DR3100型.JPG HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/test2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/white.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/train/E1000型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:48] "GET /static/img/train/E200型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/E400型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/EMU1200型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/EMU500型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/EMU300型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/EMU600型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/EMU700型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/EMU800型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/R100型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/R150型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/R20型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/TEMU2000型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/train/TEMU1000型.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:49] "GET /static/img/hiscard3.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:50] "GET /booking HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:50] "GET /static/img/ad2.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:50] "GET /static/css/style_booking.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:53] "POST /booking HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Jun/2021 17:47:53] "GET /bookingres HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:55] "POST /bookingres HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Jun/2021 17:47:55] "GET /book HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:55] "GET /static/css/style_relbook.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:55] "GET /static/js/script_rlbk.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:59] "GET /bookingres HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:59] "GET /static/img/usrimg.jpg HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:47:59] "GET /static/img/Group%201.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:48:02] "GET /booking HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:48:04] "GET /booking HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:48:07] "POST /booking HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Jun/2021 17:48:07] "GET /bookingres HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:48:14] "GET /index HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:48:29] "GET /logout HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Jun/2021 17:48:29] "GET /index HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:49:21] "GET /login HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:49:21] "GET /static/css/flash_msg.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:49:21] "GET /static/css/style_login.css HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:49:21] "GET /static/js/script_login.js HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:49:21] "GET /static/img/login.png HTTP/1.1" 200 -
# 127.0.0.1 - - [13/Jun/2021 17:49:41] "GET /facedetect HTTP/1.1" 302 -
# 127.0.0.1 - - [13/Jun/2021 17:49:41] "GET /login HTTP/1.1" 200 -

# %%
# Out:
# 1
